# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import pyplot as plt
from config import *
import os
import rasterio
from rasterio.mask import mask
from tqdm import tqdm

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
metadata_filepath = "../INPUT/01_metadata/metadata.csv"
basinatlas_filepath = "../INPUT/04_static_basinatlas_catchment_characteristics/static_basinatlas_catchment_characteristics.csv"
COMID_filepath = "../INPUT/00_geospatial_data/SWIM_gage_loc/SWIM_gage_loc.shp"
USSF_filepath = "../INPUT/00_geospatial_data/US_shapefiles/cb_2017_us_state_5m.shp"
basin_atlas_filepath = "../INPUT/00_geospatial_data/basin_atlas/"
temporal_summary_filepath = "../OUTPUT/temporal_statistics_mrb_usgs.csv"
INPUT_filepath = "../INPUT/"
shapefile_filepath = INPUT_filepath+'03_shapefiles'

# %%
# Reading and filtering 
basinatlas = pd.read_csv(basinatlas_filepath)
basinatlas = basinatlas[['STREAM_ID',
                         'ari_ix_sav', # Aridity Index (spatial ave)
                         'ppd_pk_sav', # Pop density (pop km2; spatial ave)
                         'rdd_mk_sav', # Road Density (spatial ave)
                         'ire_pc_sse', # Irrigated Area Extent (spatial ext. %)
                         'cly_pc_av', # Clay percent (SoilGrid data; top 0-5 cm)
                         'slt_pc_av', # Silt percent (SoilGrid data; top 0-5 cm)
                         'snd_pc_av', # Sand percent (SoilGrid data; top 0-5 cm)
                         'soc_th_av', # SOC (SoilGrid data; top 0-5 cm)
                        ]]

param_dict = {'clz_cl_smj_remap':'Climate Zones',
              'ari_ix_sav':'Aridity Index',
              'kar_pc_sse':'% Karst', 
              'ppd_pk_sav':'Pop. Density',
              'rdd_mk_sav':'Road Density',
              'hft_ix_s09':'Human footprint',
              'slp_dg_sav':'Terrain slope',
              'lit_cl_smj_remap':'Lithology classes',
              'ele_mt_sav':'Average elevation',
              'ire_pc_sse': 'Irrigation Extent'}

# Converting to true values
basinatlas['ari_ix_sav'] = basinatlas['ari_ix_sav']/100
basinatlas.head(20)
# Out:
#             STREAM_ID  ari_ix_sav  ppd_pk_sav  rdd_mk_sav  ire_pc_sse
# 0   STREAM-gauge-1723    1.101513   12.129693  207.375630    0.000000
# 1   STREAM-gauge-2691    1.140810   23.310343  275.694486    0.000000
# 2   STREAM-gauge-1724    1.170265   20.344044  268.232652    0.000000
# 3   STREAM-gauge-1725    1.170265   20.344044  268.232652    0.000000
# 4   STREAM-gauge-1726    1.207503   27.085210  323.501430    0.000000
# 5   STREAM-gauge-1727    1.205071   11.479416  205.618775    0.000000
# 6   STREAM-gauge-1728    1.188256    7.761126  155.511965    0.000000
# 7   STREAM-gauge-1729    1.263198   26.593396  328.203286    0.288492
# 8   STREAM-gauge-1730    1.179761   32.697727  478.343079    0.000000
# 9   STREAM-gauge-1731    1.179758   32.950085  478.360526    0.000000
# 10  STREAM-gauge-1732    1.218982    1.677012  123.552516    0.000000
# 11  STREAM-gauge-1733    1.216157    1.794317  130.365008    0.000000
# 12  STREAM-gauge-1734    1.210378   14.003463  383.351259    0.000000
# 13  STREAM-gauge-1735    1.210374    8.408630  263.116890    0.000000
# 14  STREAM-gauge-1736    1.155280   43.181603  450.021916    0.000041
# 15  STREAM-gauge-1737    1.175089   15.024457  196.766012    0.339321
# 16  STREAM-gauge-1738    1.157033   28.583614  324.112753    0.160548
# 17  STREAM-gauge-1739    1.104664   31.586517  443.557699    0.561393
# 18  STREAM-gauge-1740    1.078438   29.291142  404.469107    0.383796
# 19  STREAM-gauge-1741    1.173775   27.419347  339.963425    0.033345

# %%
# Read in shapefiles
# Get all shapefile names (without extension)
shapefile_names = [
    os.path.splitext(f)[0] 
    for f in os.listdir(shapefile_filepath) 
    if f.endswith('.shp')
]

# Check matches
ag_sites = [name for name in shapefile_names if name in main_sites]

# %%
WWTP_data = pd.read_csv(INPUT_filepath+'00_additional_data/HydroWASTE_v10/HydroWASTE_v10.csv', 
                         encoding='latin-1')
WWTP_data.head()
# Out:
#    WASTE_ID  SOURCE   ORG_ID                WWTP_NAME    COUNTRY CNTRY_ISO  \
# 0         1       1  1140441     Akmenes aglomeracija  Lithuania       LTU
# 1         2       1  1140443   Alytaus m aglomeracija  Lithuania       LTU
# 2         3       1  1140445    Anyksciu aglomeracija  Lithuania       LTU
# 3         4       1  1140447   Ariogalos aglomeracija  Lithuania       LTU
# 4         5       1  1140449  Baisogalos aglomeracija  Lithuania       LTU
#
#    LAT_WWTP  LON_WWTP  QUAL_LOC  LAT_OUT  LON_OUT        STATUS  POP_SERVED  \
# 0    56.247    22.726         2   56.223   22.627  Not Reported        1060
# 1    54.432    24.056         2   54.519   24.098  Not Reported       87900
# 2    55.509    25.073         2   55.452   25.006  Not Reported       12400
# 3    55.252    23.484         2   55.210   23.510  Not Reported        2500
# 4    55.644    23.741         2   55.681   23.835  Not Reported        1200
#
#    QUAL_POP  WASTE_DIS  QUAL_WASTE      LEVEL  QUAL_LEVEL        DF  \
# 0         2    148.213           4   Advanced           1  2421.974
# 1         2   8797.904           1   Advanced           1  2534.527
# 2         2   1959.285           1   Advanced           1  1367.809
# 3         2    578.482           1  Secondary           1  2061.969
# 4         2    167.788           4  Secondary           1   209.549
#
#      HYRIV_ID  RIVER_DIS  COAST_10KM  COAST_50KM  DESIGN_CAP  QUAL_CAP
# 0  20228874.0      4.153           0           0      4600.0         2
# 1  20261585.0    257.983           0           0    220000.0         2
# 2  20243105.0     30.995           0           0     33000.0         2
# 3  20247446.0     13.799           0           0      4357.0         2
# 4  20239330.0      0.405           0           0      1490.0         2

# %%
# Extracting WWTP density

# Create geometry from lat/lon columns (adjust column names as needed)
geometry = [Point(xy) for xy in zip(WWTP_data['LON_WWTP'], WWTP_data['LAT_WWTP'])]
WWTP_gdf = gpd.GeoDataFrame(WWTP_data, geometry=geometry, crs='EPSG:4326')

# 2. Calculate WWTP density for each matching shapefile
dens_results = []

for site in ag_sites:
    # Load the shapefile
    shp_path = f"{shapefile_filepath}/{site}.shp"
    watershed = gpd.read_file(shp_path)
    
    # Reproject to match
    watershed = watershed.to_crs(WWTP_gdf.crs)
    
    # Count WWTPs within the watershed
    wwtp_in_watershed = gpd.sjoin(WWTP_gdf, watershed, predicate='within')
    wwtp_count = len(wwtp_in_watershed)
    
    # Sum POP_SERVED and WASTE_DIS
    pop_served_total = wwtp_in_watershed['POP_SERVED'].sum()
    waste_dis_total = wwtp_in_watershed['WASTE_DIS'].sum()
    
    # Calculate area (reproject to equal-area CRS)
    watershed_projected = watershed.to_crs('EPSG:5070')  # NAD83 Albers for North America
    area_km2 = watershed_projected.geometry.area.sum() / 1e6  # m2 to km2
    
    # Density: WWTPs per 1000 km2
    density = (wwtp_count / area_km2) * 100
    
    dens_results.append({
        'site': site,
        'wwtp_num': wwtp_count,
        'pop_served_total': pop_served_total,
        'waste_dis_total_m3_d': waste_dis_total,
        'area_km2': area_km2,
        'wwtp_density_per_100km2': density
    })

# Create results DataFrame
WWTP_dens = pd.DataFrame(dens_results)
WWTP_dens.head(2)
# Out:
#                 site  wwtp_num  pop_served_total  waste_dis_total_m3_d  \
# 0  STREAM-gauge-2203      1789           9485598           4462125.993
# 1  STREAM-gauge-2804       397            756629            304543.929
#
#        area_km2  wwtp_density_per_100km2
# 0  1.277917e+06                 0.139993
# 1  1.501126e+05                 0.264468

# %%
# Tile drainage
tiledrain_raster_filepath = INPUT_filepath+'00_additional_data/AgTile-US/TIFF/AgTile-US.tif'

results = []

for site in ag_sites:
    shp_path = f"{shapefile_filepath}/{site}.shp"
    watershed = gpd.read_file(shp_path)
    
    with rasterio.open(tiledrain_raster_filepath) as src:
        # Reproject watershed to raster CRS
        watershed_reproj = watershed.to_crs(src.crs)
        
        # Mask raster to watershed boundary
        out_image, out_transform = mask(src, watershed_reproj.geometry, crop=True)
        
        # Get the data (first band)
        data = out_image[0]
        
        # Exclude nodata values (adjust nodata value as needed)
        nodata = src.nodata if src.nodata is not None else -999
        valid_data = data[data != nodata]
        
        # Calculate mean (fraction tile-drained) * 100 = percent
        pct_tile_drained = np.mean(valid_data) * 100
    
    results.append({
        'site': site,
        'pct_tile_drained': pct_tile_drained
    })

tiledrain_pct = pd.DataFrame(results)
tiledrain_pct.head(2)
# Out:
#                  site  pct_tile_drained
# 0   STREAM-gauge-2203          0.852623
# 1   STREAM-gauge-2804          0.480451
# 2   STREAM-gauge-2816          0.017967
# 3   STREAM-gauge-2886         25.264333
# 4   STREAM-gauge-2891         12.591607
# 5   STREAM-gauge-2903          1.247520
# 6   STREAM-gauge-2962          6.536015
# 7   STREAM-gauge-2963          0.597470
# 8   STREAM-gauge-3077         14.274629
# 9    STREAM-gauge-308          2.785941
# 10  STREAM-gauge-3089         26.718349
# 11  STREAM-gauge-3092         22.044554
# 12  STREAM-gauge-3096         16.706816
# 13  STREAM-gauge-3097         40.286390
# 14  STREAM-gauge-3101         27.388550
# 15  STREAM-gauge-3109         14.926199
# 16  STREAM-gauge-3776          2.128974
# 17  STREAM-gauge-4431         14.076211
# 18  STREAM-gauge-4440         22.828196
# 19  STREAM-gauge-4442         20.605570
# 20  STREAM-gauge-4465          7.674275
# 21  STREAM-gauge-4472         19.743803

# %%
# Irrigation
irrigation_raster_filepath = INPUT_filepath+'00_additional_data/Irrigation/lanid2017.tif'

results = []

for site in ag_sites:
    shp_path = f"{shapefile_filepath}/{site}.shp"
    watershed = gpd.read_file(shp_path)
    
    with rasterio.open(irrigation_raster_filepath) as src:
        # Reproject watershed to raster CRS
        watershed_reproj = watershed.to_crs(src.crs)
        
        # Mask raster to watershed boundary
        out_image, out_transform = mask(src, watershed_reproj.geometry, crop=True)
        
        # Get the data (first band)
        data = out_image[0]
        
        # Exclude nodata values (adjust nodata value as needed)
        nodata = src.nodata if src.nodata is not None else -999
        valid_data = data[data != nodata]
        
        # Calculate mean (fraction irrigated) * 100 = percent
        pct_irrigated = np.mean(valid_data) * 100
    
    results.append({
        'site': site,
        'pct_irrigated': pct_irrigated
    })

irrigated_pct = pd.DataFrame(results)
irrigated_pct.head(2)
# Out:
#                 site  pct_irrigated
# 0  STREAM-gauge-2203       2.332414
# 1  STREAM-gauge-2804       8.206287

# %%
# Pre-calculate original areas
septic_tank = gpd.read_file('../INPUT/00_additional_data/septic_tank_density/septic_tank_shapefile.shp')
septic_tank = septic_tank.to_crs('EPSG:5070')
septic_tank['Area_m2_recalc'] = septic_tank.area

results = []

for site in tqdm(ag_sites):
    shp_path = f"{shapefile_filepath}/{site}.shp"
    watershed = gpd.read_file(shp_path)
    
    # Calculate watershed area in km2
    watershed_proj = watershed.to_crs('EPSG:5070')
    area_km2 = watershed_proj.geometry.area.sum() / 1e6
    
    # Clip and calculate area-weighted septic count
    clipped = gpd.clip(septic_reproj, watershed.geometry.iloc[0])
    
    if len(clipped) > 0:
        clipped['area_fraction'] = clipped.area / clipped['Area_m2_recalc']
        septic_density_km2 = np.sum(clipped['MS_SepCnt'] * clipped['area_fraction']) / area_km2
    else:
        septic_density_km2 = 0
    
    results.append({
        'site': site,
        'septic_density_km2': septic_density_km2
    })

septic_df = pd.DataFrame(results)
# Out:
#   0%|                                                                                           | 0/22 [00:51<?, ?it/s]
# ---------------------------------------------------------------------------
# GEOSException                             Traceback (most recent call last)
# Cell In[31], line 17
#      14 area_km2 = watershed_proj.geometry.area.sum() / 1e6
#      16 # Clip and calculate area-weighted septic count
# ---> 17 clipped = gpd.clip(septic_reproj, watershed.geometry.iloc[0])
#      19 if len(clipped) > 0:
#      20     clipped['area_fraction'] = clipped.area / clipped['Area_m2_recalc']
#
# File ~\anaconda3\envs\STREAM_project\Lib\site-packages\geopandas\tools\clip.py:217, in clip(gdf, mask, keep_geom_type, sort)
#     214 else:
#     215     combined_mask = mask
# --> 217 clipped = _clip_gdf_with_mask(gdf, combined_mask, sort=sort)
#     219 if keep_geom_type:
#     220     geomcoll_concat = (clipped.geom_type == "GeometryCollection").any()
#
# File ~\anaconda3\envs\STREAM_project\Lib\site-packages\geopandas\tools\clip.py:92, in _clip_gdf_with_mask(gdf, mask, sort)
#      87         clipped.loc[non_point_mask, clipped._geometry_column_name] = (
#      88             gdf_sub.geometry.values[non_point_mask].clip_by_rect(*mask)
#      89         )
#      90     else:
#      91         clipped.loc[non_point_mask, clipped._geometry_column_name] = (
# ---> 92             gdf_sub.geometry.values[non_point_mask].intersection(mask)
#      93         )
#      94 else:
#      95     # GeoSeries
#      96     clipped = gdf_sub.copy()
#
# File ~\anaconda3\envs\STREAM_project\Lib\site-packages\geopandas\array.py:842, in GeometryArray.intersection(self, other)
#     840 def intersection(self, other):
#     841     return GeometryArray(
# --> 842         self._binary_method("intersection", self, other), crs=self.crs
#     843     )
#
# File ~\anaconda3\envs\STREAM_project\Lib\site-packages\geopandas\array.py:779, in GeometryArray._binary_method(op, left, right, **kwargs)
#     776         _crs_mismatch_warn(left, right, stacklevel=7)
#     777     right = right._data
# --> 779 return getattr(shapely, op)(left._data, right, **kwargs)
#
# File ~\anaconda3\envs\STREAM_project\Lib\site-packages\shapely\decorators.py:173, in deprecate_positional.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @wraps(func)
#     172 def wrapper(*args, **kwargs):
# --> 173     result = func(*args, **kwargs)
#     175     n = len(args)
#     176     if n > warn_from:
#
# File ~\anaconda3\envs\STREAM_project\Lib\site-packages\shapely\decorators.py:88, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      86     for arr in array_args:
#      87         arr.flags.writeable = False
# ---> 88     return func(*args, **kwargs)
#      89 finally:
#      90     for arr, old_flag in zip(array_args, old_flags):
#
# File ~\anaconda3\envs\STREAM_project\Lib\site-packages\shapely\set_operations.py:168, in intersection(a, b, grid_size, **kwargs)
#     164         raise ValueError("grid_size parameter only accepts scalar values")
#     166     return lib.intersection_prec(a, b, grid_size, **kwargs)
# --> 168 return lib.intersection(a, b, **kwargs)
#
# GEOSException: TopologyException: side location conflict at -103.05051381418535 39.786206010028408. This can occur if the input geometry is invalid.

# %%
# Summing septic tank data to watershed
results = []

for site in tqdm(ag_sites):
    shp_path = f"{shapefile_filepath}/{site}.shp"
    watershed = gpd.read_file(shp_path)
    
    # Reproject septic data to watershed CRS
    septic_reproj = septic_tank.to_crs(watershed.crs)
    
    # Calculate watershed area in km2
    watershed_proj = watershed.to_crs('EPSG:5070')
    area_km2 = watershed_proj.geometry.area.sum() / 1e6
    
    # Clip and calculate area-weighted septic count
    clipped = gpd.clip(septic_reproj, watershed.geometry.iloc[0])
    
    if len(clipped) > 0:
        clipped['area_fraction'] = clipped.area / clipped['Area_m2_recalc']
        septic_density_km2 = np.sum(clipped['MS_SepCnt'] * clipped['area_fraction']) / area_km2
    else:
        septic_density_km2 = 0
    
    results.append({
        'site': site,
        'septic_density_km2': septic_density_km2
    })

septic_df = pd.DataFrame(results)
