# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
metadata_filepath = "../INPUT/01_metadata/metadata.csv"
basinatlas_filepath = "../INPUT/04_static_basinatlas_catchment_characteristics/static_basinatlas_catchment_characteristics.csv"
COMID_filepath = "../INPUT/00_geospatial_data/SWIM_gage_loc/SWIM_gage_loc.shp"
USSF_filepath = "../INPUT/00_geospatial_data/US_shapefiles/cb_2017_us_state_5m.shp"
basin_atlas_filepath = "../INPUT/00_geospatial_data/basin_atlas/"
temporal_summary_filepath = "../OUTPUT/temporal_statistics_mrb_usgs.csv"

# %%
# Match COMIDs from data retrieval
COMID = gpd.read_file(COMID_filepath)
# Out:
# C:\Users\danyk\anaconda3\envs\STREAM_project\Lib\site-packages\pyogrio\raw.py:200: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured 3D Point' is converted to 'Point Z'
#   return ogr_read(

# %%
# Reading and filtering 
basinatlas = pd.read_csv(basinatlas_filepath)
basinatlas = basinatlas[['STREAM_ID',
                         'clz_cl_smj', # Climate Zones (spatial maj)
                         'ari_ix_sav', # Aridity Index (spatial ave)
                         'kar_pc_sse', # Karst percentage (spatial extent %)
                         'ppd_pk_sav', # Pop density (pop km2; spatial ave)
                         'rdd_mk_sav', # Road Density (spatial ave)
                         'hft_ix_s09', # Human footprint (2009)
                         'slp_dg_sav', # Terrain slope
                         'lit_cl_smj', # Lith classes (spatial maj)
                         'ele_mt_sav'  # Average elevation
                        ]]

param_dict = {'clz_cl_smj_remap':'Climate Zones',
              'ari_ix_sav':'Aridity Index',
              'kar_pc_sse':'% Karst', 
              'ppd_pk_sav':'Pop. Density',
              'rdd_mk_sav':'Road Density',
              'hft_ix_s09':'Human footprint',
              'slp_dg_sav':'Terrain slope',
              'lit_cl_smj_remap':'Lithology classes',
              'ele_mt_sav':'Average elevation'}

# Converting to true values
basinatlas['ari_ix_sav'] = basinatlas['ari_ix_sav']/100
basinatlas['slp_dg_sav'] = basinatlas['slp_dg_sav']/10
basinatlas.head(2)
# Out:
#            STREAM_ID  clz_cl_smj  ari_ix_sav  kar_pc_sse  ppd_pk_sav  \
# 0  STREAM-gauge-1723         7.0    1.101513         0.0   12.129693
# 1  STREAM-gauge-2691         7.0    1.140810         0.0   23.310343
#
#    rdd_mk_sav  hft_ix_s09  slp_dg_sav  lit_cl_smj  ele_mt_sav
# 0  207.375630   77.930846    9.251775         3.0  633.409154
# 1  275.694486  103.656822    8.274755         3.0  591.319034

# %%
# Mapping cateogorical variables
clz_cl = pd.read_csv(basin_atlas_filepath+'clz_cl.csv')
clz_cl_dict = pd.Series(clz_cl.Reclassification.values, index=clz_cl.GEnZ_ID).to_dict()

lit_cl = pd.read_csv(basin_atlas_filepath+'lit_cl.csv')
lit_cl_dict = pd.Series(lit_cl.Reclassification.values, index=lit_cl.GLiM_ID).to_dict()

basinatlas['clz_cl_smj_remap'] = basinatlas['clz_cl_smj'].map(clz_cl_dict)
basinatlas['lit_cl_smj_remap'] = basinatlas['lit_cl_smj'].map(lit_cl_dict)
basinatlas.head(2)
# Out:
#            STREAM_ID  clz_cl_smj  ari_ix_sav  kar_pc_sse  ppd_pk_sav  \
# 0  STREAM-gauge-1723         7.0    1.101513         0.0   12.129693
# 1  STREAM-gauge-2691         7.0    1.140810         0.0   23.310343
#
#    rdd_mk_sav  hft_ix_s09  slp_dg_sav  lit_cl_smj  ele_mt_sav  \
# 0  207.375630   77.930846    9.251775         3.0  633.409154
# 1  275.694486  103.656822    8.274755         3.0  591.319034
#
#    clz_cl_smj_remap lit_cl_smj_remap
# 0                 5      Sedimentary
# 1                 5      Sedimentary

# %%
# Processing metadata, isolating specific parameters
md = pd.read_csv(metadata_filepath, dtype = {'sourceID': str})
print(f"Full dataset size: {md.shape[0]}")
params = ['SpC_uScm','DO_mgL','Turb_FNU']

for param in params:
    md[param] = md['WQ_parameters'].str.contains(param)

# Removing the stations without data
md = md[(md['SpC_uScm']) | (md['DO_mgL']) | (md['Turb_FNU'])]
print(f"Filtered dataset size: {md.shape[0]}")
# Out:
# Full dataset size: 870
# Filtered dataset size: 556

# %%
# Merge COMID 
md_comid = md.merge(COMID[['Gage_no','COMID']], 
              left_on='sourceID',
              right_on='Gage_no',
             how='left')
print(f"Filtered dataset size: {md_comid.shape[0]}")
# Out:
# Filtered dataset size: 556

# %%
#md.to_csv('../OUTPUT/filtered_spC_DO_turb.csv')
md_comid.head()
# Out:
#            STREAM_ID  sourceID source  \
# 0  STREAM-gauge-1723  03007800   USGS
# 1  STREAM-gauge-1724  03012545   USGS
# 2  STREAM-gauge-1725  03012550   USGS
# 3  STREAM-gauge-1726  03016000   USGS
# 4  STREAM-gauge-1733  03027500   USGS
#
#                                           site name  latitude_wgs84  \
# 0              Allegheny River at Port Allegany, PA       41.818676
# 1  Allegheny River below Kinzua Dam at Big Bend, PA       41.838672
# 2                 Allegheny River at Kinzua Dam, PA       41.841449
# 3               Allegheny River at West Hickory, PA       41.570895
# 4      EB Clarion River at EB Clarion River Dam, PA       41.553118
#
#    longitude_wgs84  drainagearea_sqkm    state_name time_zone  \
# 0       -78.292791         642.317520  Pennsylvania   Eastern
# 1       -79.004925        5646.178200  Pennsylvania   Eastern
# 2       -79.011985        5646.178200  Pennsylvania   Eastern
# 3       -79.407824        9479.363400  Pennsylvania   Eastern
# 4       -78.596135         189.587268  Pennsylvania   Eastern
#
#                          WQ_parameters  SpC_uScm  DO_mgL  Turb_FNU   Gage_no  \
# 0           WTemp_C,SpC_uScm,DO_mgL,pH      True    True     False  03007800
# 1                       WTemp_C,DO_mgL     False    True     False       NaN
# 2                       WTemp_C,DO_mgL     False    True     False  03012550
# 3                     WTemp_C,SpC_uScm      True   False     False  03016000
# 4  WTemp_C,SpC_uScm,DO_mgL,pH,Turb_FNU      True    True      True  03027500
#
#         COMID
# 0   8972788.0
# 1         NaN
# 2   8975664.0
# 3  10220190.0
# 4   6874115.0

# %%
md_data = md_comid.merge(basinatlas, on='STREAM_ID')
md_data.head()
#md_data.to_csv('../OUTPUT/filtered_spC_DO_turb_basinparams.csv')
# Out:
#            STREAM_ID  sourceID source  \
# 0  STREAM-gauge-1723  03007800   USGS
# 1  STREAM-gauge-1724  03012545   USGS
# 2  STREAM-gauge-1725  03012550   USGS
# 3  STREAM-gauge-1726  03016000   USGS
# 4  STREAM-gauge-1733  03027500   USGS
#
#                                           site name  latitude_wgs84  \
# 0              Allegheny River at Port Allegany, PA       41.818676
# 1  Allegheny River below Kinzua Dam at Big Bend, PA       41.838672
# 2                 Allegheny River at Kinzua Dam, PA       41.841449
# 3               Allegheny River at West Hickory, PA       41.570895
# 4      EB Clarion River at EB Clarion River Dam, PA       41.553118
#
#    longitude_wgs84  drainagearea_sqkm    state_name time_zone  \
# 0       -78.292791         642.317520  Pennsylvania   Eastern
# 1       -79.004925        5646.178200  Pennsylvania   Eastern
# 2       -79.011985        5646.178200  Pennsylvania   Eastern
# 3       -79.407824        9479.363400  Pennsylvania   Eastern
# 4       -78.596135         189.587268  Pennsylvania   Eastern
#
#                          WQ_parameters  SpC_uScm  DO_mgL  Turb_FNU   Gage_no  \
# 0           WTemp_C,SpC_uScm,DO_mgL,pH      True    True     False  03007800
# 1                       WTemp_C,DO_mgL     False    True     False       NaN
# 2                       WTemp_C,DO_mgL     False    True     False  03012550
# 3                     WTemp_C,SpC_uScm      True   False     False  03016000
# 4  WTemp_C,SpC_uScm,DO_mgL,pH,Turb_FNU      True    True      True  03027500
#
#         COMID  clz_cl_smj  ari_ix_sav  kar_pc_sse  ppd_pk_sav  rdd_mk_sav  \
# 0   8972788.0         7.0    1.101513         0.0   12.129693  207.375630
# 1         NaN         7.0    1.170265         0.0   20.344044  268.232652
# 2   8975664.0         7.0    1.170265         0.0   20.344044  268.232652
# 3  10220190.0         7.0    1.207503         0.0   27.085210  323.501430
# 4   6874115.0         7.0    1.216157         0.0    1.794317  130.365008
#
#    hft_ix_s09  slp_dg_sav  lit_cl_smj  ele_mt_sav  clz_cl_smj_remap  \
# 0   77.930846    9.251775         3.0  633.409154                 5
# 1  100.881696    8.046997         3.0  585.402633                 5
# 2  100.881696    8.046997         3.0  585.402633                 5
# 3  106.949843    6.579398         3.0  543.494624                 5
# 4   39.261068    5.554338         3.0  626.424797                 5
#
#   lit_cl_smj_remap
# 0      Sedimentary
# 1      Sedimentary
# 2      Sedimentary
# 3      Sedimentary
# 4      Sedimentary

# %%
temporal_summary = pd.read_csv(temporal_summary_filepath)
md_data = md_data.merge(temporal_summary, on='STREAM_ID')

# %%
md_gdf = gpd.GeoDataFrame(md_data, 
                          geometry=gpd.points_from_xy(md_data.longitude_wgs84, md_data.latitude_wgs84), 
                          crs="EPSG:4326")
md_gdf.head(2)
# Out:
#            STREAM_ID  sourceID source  \
# 0  STREAM-gauge-1723  03007800   USGS
# 1  STREAM-gauge-1724  03012545   USGS
#
#                                           site name  latitude_wgs84  \
# 0              Allegheny River at Port Allegany, PA       41.818676
# 1  Allegheny River below Kinzua Dam at Big Bend, PA       41.838672
#
#    longitude_wgs84  drainagearea_sqkm    state_name time_zone  \
# 0       -78.292791          642.31752  Pennsylvania   Eastern
# 1       -79.004925         5646.17820  Pennsylvania   Eastern
#
#                 WQ_parameters  SpC_uScm  DO_mgL  Turb_FNU   Gage_no  \
# 0  WTemp_C,SpC_uScm,DO_mgL,pH      True    True     False  03007800
# 1              WTemp_C,DO_mgL     False    True     False       NaN
#
#        COMID  clz_cl_smj  ari_ix_sav  kar_pc_sse  ppd_pk_sav  rdd_mk_sav  \
# 0  8972788.0         7.0    1.101513         0.0   12.129693  207.375630
# 1        NaN         7.0    1.170265         0.0   20.344044  268.232652
#
#    hft_ix_s09  slp_dg_sav  lit_cl_smj  ele_mt_sav  clz_cl_smj_remap  \
# 0   77.930846    9.251775         3.0  633.409154                 5
# 1  100.881696    8.046997         3.0  585.402633                 5
#
#   lit_cl_smj_remap  WTemp_C_pct_missing  WTemp_C_length_hr  \
# 0      Sedimentary                 0.97           129087.0
# 1      Sedimentary                39.92            10974.0
#
#    WTemp_C_longest_hr  SpC_uScm_pct_missing  SpC_uScm_length_hr  \
# 0             12094.0                  4.02            129087.0
# 1              5161.0                   NaN                 NaN
#
#    SpC_uScm_longest_hr  DO_mgL_pct_missing  DO_mgL_length_hr  \
# 0               9415.0               47.38          129087.0
# 1                  NaN               42.97           10974.0
#
#    DO_mgL_longest_hr  pH_pct_missing  pH_length_hr  pH_longest_hr  \
# 0             4464.0           44.78      129087.0         3878.0
# 1             4534.0             NaN           NaN            NaN
#
#    Turb_FNU_pct_missing  Turb_FNU_length_hr  Turb_FNU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
#
#    Turb_NTU_pct_missing  Turb_NTU_length_hr  Turb_NTU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
#
#    NO3_mgNL_pct_missing  NO3_mgNL_length_hr  NO3_mgNL_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
#
#    fDOM_QSU_pct_missing  fDOM_QSU_length_hr  fDOM_QSU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
#
#    fDOM_RFU_pct_missing  fDOM_RFU_length_hr  fDOM_RFU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
#
#    DOC_mgL_pct_missing  DOC_mgL_length_hr  DOC_mgL_longest_hr  \
# 0                  NaN                NaN                 NaN
# 1                  NaN                NaN                 NaN
#
#    PO4_mgL_pct_missing  PO4_mgL_length_hr  PO4_mgL_longest_hr  \
# 0                  NaN                NaN                 NaN
# 1                  NaN                NaN                 NaN
#
#    Chla_ugL_pct_missing  Chla_ugL_length_hr  Chla_ugL_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
#
#    Chla_RFU_pct_missing  Chla_RFU_length_hr  Chla_RFU_longest_hr  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
#
#    PC_ugL_pct_missing  PC_ugL_length_hr  PC_ugL_longest_hr  \
# 0                 NaN               NaN                NaN
# 1                 NaN               NaN                NaN
#
#    PC_RFU_pct_missing  PC_RFU_length_hr  PC_RFU_longest_hr  \
# 0                 NaN               NaN                NaN
# 1                 NaN               NaN                NaN
#
#                      geometry
# 0  POINT (-78.29279 41.81868)
# 1  POINT (-79.00492 41.83867)

# %%
US_shp = gpd.read_file(USSF_filepath)

# %% [markdown]
# ## Exploring spatial patterns

# %%
md_gdf_Spc.head()
# Out:
#            STREAM_ID  sourceID source  \
# 0  STREAM-gauge-1723  03007800   USGS
# 3  STREAM-gauge-1726  03016000   USGS
# 4  STREAM-gauge-1733  03027500   USGS
# 5  STREAM-gauge-1736  03034000   USGS
# 6  STREAM-gauge-1738  03036000   USGS
#
#                                       site name  latitude_wgs84  \
# 0          Allegheny River at Port Allegany, PA       41.818676
# 3           Allegheny River at West Hickory, PA       41.570895
# 4  EB Clarion River at EB Clarion River Dam, PA       41.553118
# 5            Mahoning Creek at Punxsutawney, PA       40.939231
# 6      Mahoning Creek at Mahoning Creek Dam, PA       40.927565
#
#    longitude_wgs84  drainagearea_sqkm    state_name time_zone  \
# 0       -78.292791         642.317520  Pennsylvania   Eastern
# 3       -79.407824        9479.363400  Pennsylvania   Eastern
# 4       -78.596135         189.587268  Pennsylvania   Eastern
# 5       -79.008367         409.218420  Pennsylvania   Eastern
# 6       -79.291151         890.956560  Pennsylvania   Eastern
#
#                          WQ_parameters  SpC_uScm  DO_mgL  Turb_FNU   Gage_no  \
# 0           WTemp_C,SpC_uScm,DO_mgL,pH      True    True     False  03007800
# 3                     WTemp_C,SpC_uScm      True   False     False  03016000
# 4  WTemp_C,SpC_uScm,DO_mgL,pH,Turb_FNU      True    True      True  03027500
# 5           WTemp_C,SpC_uScm,DO_mgL,pH      True    True     False  03034000
# 6           WTemp_C,SpC_uScm,DO_mgL,pH      True    True     False  03036000
#
#          COMID  clz_cl_smj  ari_ix_sav  kar_pc_sse  ppd_pk_sav  rdd_mk_sav  \
# 0    8972788.0         7.0    1.101513    0.000000   12.129693  207.375630
# 3   10220190.0         7.0    1.207503    0.000000   27.085210  323.501430
# 4    6874115.0         7.0    1.216157    0.000000    1.794317  130.365008
# 5    4741709.0        10.0    1.155280   68.797004   43.181603  450.021916
# 6  166808422.0        10.0    1.157033   68.379352   28.583614  324.112753
#
#    hft_ix_s09  slp_dg_sav  lit_cl_smj  ele_mt_sav  clz_cl_smj_remap  \
# 0   77.930846    9.251775         3.0  633.409154                 5
# 3  106.949843    6.579398         3.0  543.494624                 5
# 4   39.261068    5.554338         3.0  626.424797                 5
# 5  131.517594    5.275403         3.0  488.056823                 6
# 6  109.585831    5.644361         3.0  471.156757                 6
#
#   lit_cl_smj_remap                    geometry
# 0      Sedimentary  POINT (-78.29279 41.81868)
# 3      Sedimentary   POINT (-79.40782 41.5709)
# 4      Sedimentary  POINT (-78.59614 41.55312)
# 5      Sedimentary  POINT (-79.00837 40.93923)
# 6      Sedimentary  POINT (-79.29115 40.92756)

# %%
MAP_COLOR = '#2563EB'
HIST_COLOR = '#80cdc1'
HIST_EDGE = '#018571'
BG_COLOR = '#FFFFFF'
GRID_COLOR = '#E5E7EB'

params = {
    'DO_mgL': 'DO',
    'SpC_uScm': 'Cond.',
    'Turb_FNU': 'Turb.'
}

vars_cat = ['lit_cl_smj_remap']
vars_cont = ['hft_ix_s09', 'ari_ix_sav', 'rdd_mk_sav', 'ele_mt_sav']

# Shared x-axis limits for histograms
shared_xlims = {}
for var in vars_cont:
    global_min = min(md_gdf[md_gdf[p] == True][var].min() for p in params)
    global_max = max(md_gdf[md_gdf[p] == True][var].max() for p in params)
    margin = (global_max - global_min) * 0.05
    shared_xlims[var] = (global_min - margin, global_max + margin)

for param_col, param_label in params.items():
    md_gdf_filt = md_gdf[md_gdf[param_col] == True]

    # Create gridspec: map with marginal histograms + bar + 4 histograms
    fig = plt.figure(figsize=(14, 8))
    gs = fig.add_gridspec(2, 3, hspace=0.4, wspace=0.3)

    # --- Map with marginal distributions ---
    # Sub-gridspec for map cell (top-left)
    gs_map = gs[0, 0].subgridspec(2, 2, width_ratios=[4, 1], height_ratios=[1, 4], 
                                  hspace=0.0, wspace=0.0)
    
    ax_map = fig.add_subplot(gs_map[1, 0])
    ax_top = fig.add_subplot(gs_map[0, 0], sharex=ax_map)
    ax_right = fig.add_subplot(gs_map[1, 1], sharey=ax_map)

    # Main map
    US_shp.plot(ax=ax_map, facecolor='none', edgecolor='black', linewidth=0.5)
    md_gdf_filt.plot(ax=ax_map, color=HIST_EDGE, markersize=8,
                     alpha=0.6, edgecolor=HIST_EDGE, linewidth=0.3)
    ax_map.tick_params(labelsize=7, colors='#374151')
    ax_map.spines[['top', 'right']].set_visible(False)
    ax_map.spines[['top', 'left']].set_color(GRID_COLOR)

    # Longitude distribution (top)
    lons = md_gdf_filt.geometry.x
    lats = md_gdf_filt.geometry.y
    ax_top.hist(lons, bins=40, color=HIST_COLOR, edgecolor=HIST_EDGE, linewidth=0.4, alpha=0.8)
    ax_top.set_title(f'Stations with ≥1 meas. of {param_label}',
                     fontsize=10, fontweight='bold', pad=6)
    ax_top.tick_params(labelbottom=False, labelleft=False, left=False, bottom=False)
    ax_top.spines[['top', 'right', 'left', 'bottom']].set_visible(False)

    # Latitude distribution (right)
    ax_right.hist(lats, bins=40, orientation='horizontal',
                  color=HIST_COLOR, edgecolor=HIST_EDGE, linewidth=0.4, alpha=0.8)
    ax_right.tick_params(labelbottom=False, labelleft=False, left=False, bottom=False)
    ax_right.spines[['top', 'right', 'left', 'bottom']].set_visible(False)

    # --- Bar chart ---
    cntr = 1
    ax_bar = fig.add_subplot(gs[0, 1])
    for i, var in enumerate(vars_cat):
        cntr += 1
        counts = md_gdf_filt[var].value_counts().sort_index()
        ax_bar.bar(counts.index, counts.values,
                   color=HIST_COLOR, edgecolor=HIST_EDGE, linewidth=0.8, alpha=0.85)
        ax_bar.set_title(param_dict[var], fontsize=11, fontweight='bold', pad=10)
        ax_bar.set_facecolor(BG_COLOR)
        ax_bar.spines[['top', 'right']].set_visible(False)
        ax_bar.spines[['left', 'bottom']].set_color(GRID_COLOR)
        ax_bar.tick_params(colors='#374151', labelsize=9)
        ax_bar.yaxis.grid(True, color=GRID_COLOR, linewidth=0.5, alpha=0.7)
        ax_bar.set_axisbelow(True)
        ax_bar.tick_params(axis='x', rotation=45)

    # --- Histograms (remaining slots) ---
    hist_positions = [(0, 2), (1, 0), (1, 1), (1, 2)]
    for j, var in enumerate(vars_cont):
        row, col = hist_positions[j]
        a = fig.add_subplot(gs[row, col])
        a.hist(md_gdf_filt[var], bins=30,
               color=HIST_COLOR, edgecolor=HIST_EDGE, linewidth=0.6, alpha=0.8)
        a.set_xlim(shared_xlims[var])
        a.set_title(param_dict[var], fontsize=11, fontweight='bold', pad=10)
        a.set_facecolor(BG_COLOR)
        a.spines[['top', 'right']].set_visible(False)
        a.spines[['left', 'bottom']].set_color(GRID_COLOR)
        a.tick_params(colors='#374151', labelsize=9)
        a.yaxis.grid(True, color=GRID_COLOR, linewidth=0.5, alpha=0.7)
        a.set_axisbelow(True)

    plt.savefig(f'../OUTPUT/{param_col}_spatial_distributions.png', dpi=150, bbox_inches='tight')
    plt.show()
